# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanGruzdev/LUXKOD/blob/main/LuxKod3(23_10_23).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LESSON2

# %% [markdown]
# ПОЛУЧЕНИЕ ПЕРВИЧНОЙ ИНФОРМАЦИИ

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from sklearn.preprocessing import MinMaxScaler
pd.options.display.max_columns=40

# %%
df = pd.read_csv('/content/hotel_bookings (1).csv')

# %%
display(df.head())
display(df.describe())
display(df.info())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ВИЗУАЛЬНЫЙ АНАЛИЗ ДАННЫХ

# %% [markdown]
# ТИП ОТЕЛЯ

# %%
sns.countplot(x = 'hotel',data = df);

# %% [markdown]
# МЕСЯЦ БРОНИРОВАНИЯ

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'arrival_date_month',data = df);

# %% [markdown]
# ПИТАНИЕ

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'meal',data = df);

# %% [markdown]
# СТРАНА

# %%
top_country = df.groupby('country')['hotel'].count().sort_values(ascending=False).head(10)
top_country.plot(kind='bar', figsize = (10,3));

# %% [markdown]
# СЕГМЕНТ МАРКЕТИНГА

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'market_segment',data = df);

# %% [markdown]
# КАНАЛ БРОНИРОВАНИЯ

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'distribution_channel',data = df);

# %% [markdown]
# НАЛИЧИЕ ДЕПОЗИТА

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'deposit_type',data = df);

# %% [markdown]
# ТИП БРОНИРОВАНИЯ

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'customer_type',data = df);

# %% [markdown]
# РАСПРЕДЕЛЕНИЕ ЧИСЛОВЫХ ПРИЗНАКОВ

# %%
df.hist(bins = 20, figsize = (20,20));

# %% [markdown]
# ВЗАИМОСВЯЗЬ ПРИЗНАКОВ

# %% [markdown]
# ВЗАИМОСВЯЗЬ ЦЕНЫ НОМЕРА И МЕСЯЦА ЗАЕЗДА

# %%
plt.figure(figsize=(15,5))
sns.barplot(data = df, x = 'arrival_date_month', y = 'adr',hue = 'hotel')
plt.legend(loc='upper right');

# %% [markdown]
# ВЗАИМОСВЯЗЬ ТИПА ПИТАНИЯ И КОЛИЧЕСТВА ДЕТЕЙ

# %%
sns.barplot(data = df, x = 'meal', y = 'children',hue = 'hotel')
plt.legend(loc='upper right');

# %% [markdown]
# ВЗАИМОСВЯЗЬ МЕСЯЦА ПРОЖИВАНИЯ И КОЛИЧЕСТВА МЛАДЕНЦЕВ

# %%
plt.figure(figsize=(15,5))
sns.barplot(data = df, x = 'arrival_date_month', y = 'babies',hue = 'hotel')
plt.legend(loc='upper right');

# %% [markdown]
# КОРРЕЛЯЦИЯ ЧИСЛОВЫХ ПРИЗНАКОВ

# %%
corr_df = df.corr()
# Out:
# <ipython-input-17-a021b72fbf12>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = df.corr()

# %%
sns.set(font_scale=0.8)
plt.figure(figsize=(10,7))
plt.title('Зависимость признаков друг от друга')
sns.heatmap(corr_df,cmap='RdBu_r',
    annot=True,
    vmin=-1, vmax=1,fmt='.1f');

# %% [markdown]
# ОБРАБОТКА ДАННЫХ

# %% [markdown]
# Обработка пустых значений

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df = df.dropna (subset=['country','children'])

# %%
df = df.drop(['agent', 'company'], axis=1)

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# Обработка дубликатов

# %%
df.duplicated(subset=['arrival_date_year','arrival_date_day_of_month','arrival_date_month']).sum()
# Out:
# 118105

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (86914, 30)

# %% [markdown]
# Выбросы

# %%
recovery_list = ['lead_time','arrival_date_year','arrival_date_week_number','arrival_date_day_of_month',
                 'stays_in_week_nights','stays_in_weekend_nights',
                'adults', 'children', 'babies',
                'previous_cancellations', 'previous_bookings_not_canceled',
                'booking_changes', 'days_in_waiting_list',
                'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['lead_time'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['stays_in_weekend_nights'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['stays_in_week_nights'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['adults'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['children'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['babies'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['previous_cancellations'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['previous_bookings_not_canceled'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['booking_changes'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['days_in_waiting_list'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['adr'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['required_car_parking_spaces'],orient='h');

# %%
plt.figure(figsize=(4,2))
sns.boxplot(df['total_of_special_requests'],orient='h');

# %%
z_scores = np.abs(stats.zscore(df[recovery_list]))
treshold = 3
z_scores
# Out:
#         lead_time  arrival_date_year  arrival_date_week_number  \
# 0        3.040534           1.766572                  0.011594
# 1        7.628094           1.766572                  0.011594
# 2        0.850182           1.766572                  0.011594
# 3        0.780498           1.766572                  0.011594
# 4        0.768884           1.766572                  0.011594
# ...           ...                ...                       ...
# 119385   0.664357           1.148944                  0.597502
# 119386   0.253155           1.148944                  0.597502
# 119387   0.536602           1.148944                  0.597502
# 119388   0.334454           1.148944                  0.597502
# 119389   1.449405           1.148944                  0.597502
#
#         arrival_date_day_of_month  stays_in_week_nights  \
# 0                        1.677341              1.286277
# 1                        1.677341              1.286277
# ...

# %%
outliers = df[(z_scores > treshold).any(axis=1)]
outliers.head()
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 25  Resort Hotel            0         78               2015
# 29  Resort Hotel            0         99               2015
# 31  Resort Hotel            0         95               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                July                        27                          1
# 1                July                        27                          1
# 25               July                        27                          1
# 29               July                        27                          1
# 31               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# ...

# %%
df_no_outliers = df[(z_scores <= treshold).all(axis=1)]
df_no_outliers.shape
# Out:
# (70465, 30)

# %% [markdown]
# Изменение типов данных

# %%
df_no_outliers['reservation_status_date'] = pd.to_datetime(df_no_outliers['reservation_status_date'])
# Out:
# <ipython-input-45-b6023712d3e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['reservation_status_date'] = pd.to_datetime(df_no_outliers['reservation_status_date'])

# %%
df_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70465 entries, 2 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           70465 non-null  object
#  1   is_canceled                     70465 non-null  int64
#  2   lead_time                       70465 non-null  int64
#  3   arrival_date_year               70465 non-null  int64
#  4   arrival_date_month              70465 non-null  object
#  5   arrival_date_week_number        70465 non-null  int64
#  6   arrival_date_day_of_month       70465 non-null  int64
#  7   stays_in_weekend_nights         70465 non-null  int64
#  8   stays_in_week_nights            70465 non-null  int64
#  9   adults                          70465 non-null  int64
#  10  children                        70465 non-null  float64
#  11  babies                          70465 non-null  int64
# ...

# %% [markdown]
# МАСШТАБИРОВАНИЕ

# %%
scaler = MinMaxScaler()

# %%
scaler.fit_transform(df[recovery_list])
# Out:
# array([[0.46404342, 0.        , 0.5       , ..., 0.00118009, 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.5       , ..., 0.00118009, 0.        ,
#         0.        ],
#        [0.00949796, 0.        , 0.5       , ..., 0.01505259, 0.        ,
#         0.        ],
#        ...,
#        [0.04613297, 1.        , 0.65384615, ..., 0.03035118, 0.        ,
#         0.8       ],
#        [0.14789688, 1.        , 0.65384615, ..., 0.02049061, 0.        ,
#         0.        ],
#        [0.27815468, 1.        , 0.65384615, ..., 0.02914704, 0.        ,
#         0.4       ]])
